# %%
import pandas as pd

data = pd.read_excel('../../data/raw/clinical/seqlist.xlsx')
data
# Out:
#      Study REB#         Sample ID        Research ID Study ID   \
# 0    1000070060  20-11012-A-02-00         01C0397v1E     C0397
# 1    1000070060   21-1157-A-02-00         01C0109v1E     C0109
# 2    1000070060   21-1532-A-02-00         01C0091v1E     C0091
# 3    1000070060   21-1867-A-02-00         01C0466v1E     C0466
# 4    1000070060   21-4541-A-02-00         01C0591v1E     C0591
# ..          ...               ...                ...       ...
# 132  1000070060   21-8367-A-02-00  Site 1;C0349;P;01     C0349
# 133  1000070060   21-8384-A-02-00  Site 1;C0568;P;01     C0568
# 134  1000070060  21-20577-A-02-00         01C0827v1E     C0827
# 135  1000070060  21-21225-A-02-00         01C0838v1E     C0838
# 136  1000070060  21-21725-A-02-00         01C0830v1E     C0830
#
#     MIS-C postive, COVID+ MIS-C positive, COVID- COVID+ (no MIS-C)
# 0                       Y                    NaN               NaN
# 1                       Y                    NaN               NaN
# ...
